# %%
import pandas as pd 
dataset = pd.read_csv("Placement.csv")
dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
from Univariate_analysis import Univariate
import pandas as pd 
uni_con = Univariate(dataset)
quan, qual = uni_con.quanQual()
print('quan',quan,'qual',qual)
univariate_continuous = uni_con.univariate_continuous(quan)
univariate_continuous
# Out:
# quan ['sl_no', 'ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'salary'] qual ['gender', 'ssc_b', 'hsc_b', 'hsc_s', 'degree_t', 'workex', 'specialisation', 'status']
#                  sl_no       ssc_p       hsc_p   degree_p     etest_p  \
# Mean             108.0   67.303395   66.333163  66.370186   72.100558
# Median           108.0        67.0        65.0       66.0        71.0
# Mode                 1        62.0        63.0       65.0        60.0
# Q1:25%            54.5        60.6        60.9       61.0        60.0
# Q2:50%           108.0        67.0        65.0       66.0        71.0
# Q3:75%           161.5        75.7        73.0       72.0        83.5
# 99%             212.86        87.0       91.86      83.86        97.0
# Q4:100%          215.0        89.4        97.7       91.0        98.0
# IQR              107.0        15.1        12.1       11.0        23.5
# 1.5_rule         160.5       22.65       18.15       16.5       35.25
# ...

# %% [markdown]
# ## 1)Replace the NaN values with correct value. And justify why you have chosen the same

# %%
dataset.isnull().sum()
# Out:
# sl_no              0
# gender             0
# ssc_p              0
# ssc_b              0
# hsc_p              0
# hsc_b              0
# hsc_s              0
# degree_p           0
# degree_t           0
# workex             0
# etest_p            0
# specialisation     0
# mba_p              0
# status             0
# salary            67
# dtype: int64

# %%
dataset.fillna({'salary': 0},inplace=True)      # handling missing values in salary column

# %%
dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
print(dataset.isnull().sum())   # now i do not have any null values 
print(" I replaced the NaN (missing) values with zero for the non-placed students. I considered this an appropriate choice because we cannot remove the salary column, and filling it with the mean, median, or mode would produce inaccurate results. If we used those methods, it would incorrectly imply that non-placed students received a salary, which is a wrong assumption. Since predicting those values using a semi-supervised learning approach was not feasible in this case, filling the missing salary values with zero was the most appropriate solution for handling missing data in this placement dataset.")
# Out:
# sl_no             0
# gender            0
# ssc_p             0
# ssc_b             0
# hsc_p             0
# hsc_b             0
# hsc_s             0
# degree_p          0
# degree_t          0
# workex            0
# etest_p           0
# specialisation    0
# mba_p             0
# status            0
# salary            0
# dtype: int64
#  I replaced the NaN (missing) values with zero for the non-placed students. I considered this an appropriate choice because we cannot remove the salary column, and filling it with the mean, median, or mode would produce inaccurate results. If we used those methods, it would incorrectly imply that non-placed students received a salary, which is a wrong assumption. Since predicting those values using a semi-supervised learning approach was not feasible in this case, filling the missing salary values with zero was the most appropriate solution for handling missing data in this placement dataset.

# %% [markdown]
# ## 2)How many of them are not placed?

# %%
# using frequency
freqTable = uni_con.freqTable('status') 
print(f"The no of students not get placed after MBA ==>  '{(dataset['status']).value_counts()['Not Placed']}' " )

freqTable
# Out:
# The no of students not get placed after MBA ==>  '67'
#   Unique_values  Frequency  Relative_frequency  Cumsum
# 0        Placed        148                74.0    74.0
# 1    Not Placed         67                33.5   107.5

# %% [markdown]
# ## 3)Find the reason for non placement from the dataset

# %%
not_placed_data = dataset[dataset['status']=='Not Placed']
not_placed_data
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 3        4      M   56.0  Central   52.0  Central   Science     52.00
# 5        6      M   55.0   Others   49.8   Others   Science     67.25
# 6        7      F   46.0   Others   49.2   Others  Commerce     79.00
# 9       10      M   58.0  Central   70.0  Central  Commerce     61.00
# 12      13      F   47.0  Central   55.0   Others   Science     65.00
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 198    199      F   67.0  Central   70.0  Central  Commerce     65.00
# 201    202      M   54.2  Central   63.0   Others   Science     58.00
# 206    207      M   41.0  Central   42.0  Central   Science     60.00
# 208    209      F   43.0  Central   60.0   Others   Science     65.00
# 214    215      M   62.0  Central   58.0   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status  salary
# ...

# %%
placement_by_spec = not_placed_data.groupby('specialisation')['status'].value_counts()
placement_by_spec
# Out:
# specialisation  status
# Mkt&Fin         Not Placed    25
# Mkt&HR          Not Placed    42
# Name: count, dtype: int64

# %%
placement_by_spec = not_placed_data.groupby('degree_t')['status'].value_counts()
placement_by_spec
# Out:
# degree_t   status
# Comm&Mgmt  Not Placed    43
# Others     Not Placed     6
# Sci&Tech   Not Placed    18
# Name: count, dtype: int64

# %%
import scipy.stats as st
''' there is a significant difference between these columns '''
st.f_oneway(not_placed_data['etest_p'],not_placed_data['mba_p'], not_placed_data['ssc_p'], not_placed_data['hsc_p'])
# Out:
# F_onewayResult(statistic=23.49722150449528, pvalue=1.6394520300054095e-13)

# %%
''' average academic scorers '''
from Univariate_analysis import Univariate
import pandas as pd 
uni_con = Univariate(not_placed_data)
quan, qual = uni_con.quanQual()
print('quan',quan,'qual',qual)
univariate_continuous = uni_con.univariate_continuous(quan)
univariate_continuous
# Out:
# quan ['sl_no', 'ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'salary'] qual ['gender', 'ssc_b', 'hsc_b', 'hsc_s', 'degree_t', 'workex', 'specialisation', 'status']
#                    sl_no      ssc_p      hsc_p   degree_p    etest_p  \
# Mean          110.477612   57.54403  58.395522  61.134179   69.58791
# Median             107.0      56.28      60.33       61.0       67.0
# Mode                   4       52.0       62.0       65.0       60.0
# Q1:25%              48.5       52.0       51.0       57.0       60.0
# Q2:50%             107.0      56.28      60.33       61.0       67.0
# Q3:75%             170.5       63.0       64.0       65.0       76.5
# 99%               211.04     76.612    79.5778      78.01     96.109
# Q4:100%            215.0       77.8       82.0       79.0       97.0
# IQR                122.0       11.0       13.0        8.0       16.5
# 1.5_rule           183.0       16.5       19.5       12.0      24.75
# ...

# %% [markdown]
# #### The reason for non-placement observed in the dataset is that most of the non-placed students have chosen Marketing and HR as their specialization. In their undergraduate degree, many of them come from Commerce and Management backgrounds. Additionally, their academic scores show a noticeable decline, and most of them have average performance across all academic stages. The scores from SSLC, HSC, Degree, E-test, and MBA are mostly average, which appears to be a major factor influencing their non-placement and ultimately affecting salary outcomes.

# %% [markdown]
# ## 4)What kind of relation between salary and mba_p

# %%
dataset[quan].corr()
# Out:
#              sl_no     ssc_p     hsc_p  degree_p   etest_p     mba_p    salary
# sl_no     1.000000 -0.078155 -0.085711 -0.088281  0.063636  0.022327  0.002543
# ssc_p    -0.078155  1.000000  0.511472  0.538404  0.261993  0.388478  0.538090
# hsc_p    -0.085711  0.511472  1.000000  0.434206  0.245113  0.354823  0.452569
# degree_p -0.088281  0.538404  0.434206  1.000000  0.224470  0.402364  0.408371
# etest_p   0.063636  0.261993  0.245113  0.224470  1.000000  0.218055  0.186988
# mba_p     0.022327  0.388478  0.354823  0.402364  0.218055  1.000000  0.139823
# salary    0.002543  0.538090  0.452569  0.408371  0.186988  0.139823  1.000000

# %% [markdown]
# kind of relation between salary and mba_p = positive correlation
#
# mba_p marks is directly impacting the salary

# %% [markdown]
# ##  5)Which specialization is getting minimum salary ?

# %%
data = dataset.groupby('specialisation')['salary'].min()
print(f"the following specialization is getting minimum salary -> {data.index}")

data
# Out:
# the following specialization is getting minimum salary -> Index(['Mkt&Fin', 'Mkt&HR'], dtype='object', name='specialisation')
# specialisation
# Mkt&Fin    0.0
# Mkt&HR     0.0
# Name: salary, dtype: float64

# %% [markdown]
# ##  6)How many of them getting above 500000 salary ?

# %%
len(dataset[dataset['salary'] > 500000])
# Out:
# 3

# %% [markdown]
# ## 7)Test the Analysis of Variance between etest_p and mba_p at signifance level 5%.(Make decision using Hypothesis Testing)

# %%
# anova - one way classification 
import scipy.stats as st
st.f_oneway(dataset['etest_p'],dataset['mba_p'])
# Out:
# F_onewayResult(statistic=98.64487057324708, pvalue=4.672547689133693e-21)

# %% [markdown]
# p value = 4.672547689133693e-21   < 0.05   --> reject H0 accept H1 = alternate hypothesis
#
# There is a significant difference between etest_p and mba_p

# %% [markdown]
# ## 8)Test the similarity between the degree_t(Sci&Tech) and specialisation(Mkt&HR) with respect to salary at significance level of 5%.(Make decision using Hypothesis Testing)

# %%
# different group - same condition -> unpaired t test 
from scipy.stats import ttest_ind
degree = dataset[dataset['degree_t']=='Sci&Tech']['salary']
specialisation = dataset[dataset['specialisation']=='Mkt&HR']['salary']
ttest_ind(degree,specialisation)
# Out:
# TtestResult(statistic=2.692041243555374, pvalue=0.007897969943471191, df=152.0)

# %% [markdown]
# p value = 0.007897969943471191    < 0.05  => reject H0 accept H1 = alternate hypothesis
#
# There is a significant difference between degree_t(Sci&Tech) and specialisation(Mkt&HR) with respect to salary

# %% [markdown]
# ## 9)Convert the normal distribution to standard normal distribution for salary column

# %%
import seaborn as sns
sns.distplot(dataset['salary'])    # Normal distribution
# Out:
# C:\Users\acer\AppData\Local\Temp\ipykernel_848\311324832.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataset['salary'])    # Normal distribution
# <Axes: xlabel='salary', ylabel='Density'>

# %%
mean = dataset['salary'].mean()
stdDev = dataset['salary'].std()
z_score = [ (i-mean)/stdDev for i in dataset['salary'].values]

import seaborn as sns
sns.distplot(z_score)       # standard normal distribution
# Out:
# C:\Users\acer\AppData\Local\Temp\ipykernel_848\3112337670.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(z_score)       # standard normal distribution
# <Axes: ylabel='Density'>

# %% [markdown]
# ## 10)What is the probability Density Function of the salary range from 700000 to 900000 ?

# %%
def get_pdf_propability(dataset_col, startRange, endRange):
    import seaborn as sns 
    import matplotlib.pyplot as plt 
    from scipy.stats import norm 

    # distribution plot 
    axis = sns.displot(dataset_col, kde=True, color='green')
    plt.axvline(startRange, color='red')
    plt.axvline(endRange, color='red')
    
    # calculate mean stdDev
    mean=dataset_col.mean()
    stdDev = dataset_col.std()
    print('mean: ', mean,'\nstdDev: ', stdDev)
    
    # norm 
    norm_dist = norm(mean,stdDev)
    
    # pdf
    values = [ i for i in range(startRange, endRange) ]
    pdf = [ norm_dist.pdf(value) for value in values]
    total_pdf = sum(pdf)

    return total_pdf

# %%
get_pdf_propability(dataset['salary'],700000, 900000)
# Out:
# 0.0005973310593974868

# %% [markdown]
# ## 11)Test the similarity between the degree_t(Sci&Tech)with respect to etest_p and mba_p at significance level of 5%.(Make decision using Hypothesis Testing)

# %%
# same group - different condition -> paired t test 
from scipy.stats import ttest_rel
dt_etest=dataset[dataset['degree_t']=='Sci&Tech']['etest_p']
dt_mba=dataset[dataset['degree_t']=='Sci&Tech']['mba_p'] 
ttest_rel(dt_etest, dt_mba)
# Out:
# TtestResult(statistic=5.0049844583693615, pvalue=5.5179206005054e-06, df=58)

# %% [markdown]
# p value = 5.5179206005054e-06   < 0.05  => reject H0 accept H1 = alternate hypothesis
#
# There is a significant difference between the degree_t(Sci&Tech)with respect to etest_p and mba_p

# %% [markdown]
# ##  12)Which parameter is highly correlated with salary?

# %%
dataset[quan].corr()
# Out:
#              sl_no     ssc_p     hsc_p  degree_p   etest_p     mba_p    salary
# sl_no     1.000000 -0.078155 -0.085711 -0.088281  0.063636  0.022327  0.002543
# ssc_p    -0.078155  1.000000  0.511472  0.538404  0.261993  0.388478  0.538090
# hsc_p    -0.085711  0.511472  1.000000  0.434206  0.245113  0.354823  0.452569
# degree_p -0.088281  0.538404  0.434206  1.000000  0.224470  0.402364  0.408371
# etest_p   0.063636  0.261993  0.245113  0.224470  1.000000  0.218055  0.186988
# mba_p     0.022327  0.388478  0.354823  0.402364  0.218055  1.000000  0.139823
# salary    0.002543  0.538090  0.452569  0.408371  0.186988  0.139823  1.000000

# %% [markdown]
# 'ssc_p' mark column is highly correlated with salary

# %% [markdown]
# ## 13) plot any useful graph and explain it.

# %%
# normal distribution plot 
import seaborn as sns 
sns.displot(dataset['ssc_p'], kde=True)
